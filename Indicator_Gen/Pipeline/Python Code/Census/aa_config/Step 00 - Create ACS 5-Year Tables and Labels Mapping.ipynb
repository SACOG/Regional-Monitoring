# %%
# General
import numpy as np
import pandas as pd
import os


# Geographic
from census import Census
import censusdata as acs

# %%
# Working directory
rootpath = os.path.dirname(os.getcwd())
print(rootpath)

# Set file paths
path_out = os.path.join(rootpath, 'Python Output')
# Out:
# C:\Users\jfontes\Documents\Projects\Regional Progress Report

# %%
# gather all transportation variables
# rename columns
# clean label field

# df_vars = pd.DataFrame(acs.search('acs5', 2019, 'concept', 'transportation'))
df_vars = pd.DataFrame(acs.search('acs5', 2019, 'label', 'Total'))


df_vars.columns = ['ID', 'Table Name', 'Label']
df_vars['Label_clean'] = df_vars['Label'].str.replace('Estimate!!', '')
df_vars['Label_clean'] = df_vars['Label_clean'].str.replace('!!', ' ')
df_vars['Label_clean'] = df_vars['Label_clean'].str.replace(':', '')

# show
df_vars.head()
# Out:
#              ID                Table Name  \
# 0  B01001A_001E  SEX BY AGE (WHITE ALONE)
# 1  B01001A_002E  SEX BY AGE (WHITE ALONE)
# 2  B01001A_003E  SEX BY AGE (WHITE ALONE)
# 3  B01001A_004E  SEX BY AGE (WHITE ALONE)
# 4  B01001A_005E  SEX BY AGE (WHITE ALONE)
#
#                                      Label                Label_clean
# 0                         Estimate!!Total:                      Total
# 1                  Estimate!!Total:!!Male:                 Total Male
# 2   Estimate!!Total:!!Male:!!Under 5 years   Total Male Under 5 years
# 3    Estimate!!Total:!!Male:!!5 to 9 years    Total Male 5 to 9 years
# 4  Estimate!!Total:!!Male:!!10 to 14 years  Total Male 10 to 14 years

# %%
# Export locally
df_vars.to_excel(os.path.join(path_out, 'ACS 5-Year Estimates Variable Tables and Labels 2019.xlsx'), index=False)
