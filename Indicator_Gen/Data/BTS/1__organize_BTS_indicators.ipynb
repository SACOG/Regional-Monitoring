# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import re
from datetime import date
import requests
import ast
import xlwt
from xlwt.Workbook import *
from pandas import ExcelWriter
import xlsxwriter
import time
import functools as ft
import urllib.request, json 
pd.set_option('display.max_columns', None)

# %%
# Define user
user = os.getlogin()
path_users = os.path.join('C:\\Users', user)

## Set file paths
if user == 'jfontes':
    # Git
    path_git = os.path.join(path_users, 'Documents', 'Projects', 'Regional-Monitoring', 'Indicator_Gen')

    # SharePoint
    path_out  = os.path.join(path_users
                             , 'Sacramento Area Council of Governments\Regional Monitoring and Reporting - Documents'
                             , 'Process Revamp'
                             , 'Task 9. Collect new data'
                             , 'BTS')

path_code    = os.path.join(path_git, 'Data', 'BTS')
path_config0 = os.path.join(path_git , 'config')
path_config  = os.path.join(path_code, 'config')

# %%
## User defined functions
exec(open(os.path.join(path_config0, 'Functions.py')).read())

# %%
path_in = os.path.join(path_users, 'Downloads', 'DL_SelectFields (1)')

# %%
df_bts = pd.read_csv(os.path.join(path_in, 'T_T100_SEGMENT_ALL_CARRIER.csv'))
df_bts.head()

# %%
print('Bay Area passengers:')
df_bay = df_bts.copy()
df_bay = df_bay[df_bay['ORIGIN'].isin(['SFO', 'OAK', 'SJC', 'STS'])]
df_bay = df_bay.reset_index(drop=True)
display(df_bay.head())
print(''); print('')

print('Sacramento passengers:')
df_smf = df_bts.copy()
df_smf = df_smf[df_smf['ORIGIN'].isin(['SMF', 'SAC'])]
df_smf = df_smf.reset_index(drop=True)
display(df_smf.head())

# %%
df_bay.PASSENGERS.sum()

# %%
df_bts[df_bts['ORIGIN'] == 'STS']
